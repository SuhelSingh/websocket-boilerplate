# %%
import requests
import sqlalchemy
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Postgres Demo

# %%
import pandas as pd

# %%
from sqlalchemy import Table, Column
from sqlalchemy.dialects import postgresql as pgt

# %%
from pg import get_pg
pg = get_pg('estimate')

# %% [raw]
# ### Create the database
# from pg import get_pg
# pg = get_pg('sandbox')
# pg.execute("""
# CREATE DATABASE estimate
# """)

# %% [raw]
# ### Create a v1 schema
# pg = get_pg('estimate')
# pg.execute("""
# CREATE SCHEMA v1
# """)
# pg.read("""SELECT schema_name FROM information_schema.schemata;""")

# %%
### Show schemas
pg.read("""SELECT schema_name FROM information_schema.schemata;""")
# Out:
#           schema_name
# 0            pg_toast
# 1          pg_catalog
# 2              public
# 3  information_schema
# 4                  v1
# 5                  v2

# %%
### Reflect the metadata
meta = sqlalchemy.MetaData(bind=pg.engine,schema='v1')
meta.reflect()

# %%
### Show tables
pd.Series([str(t) for t in meta.tables])
#pd.DataFrame({k:t.__dict__ for k,t in meta.tables.items()}).T
# Out:
# 0     v1.raw_events
# 1    v1.raw_events2
# dtype: object

# %%
pg.read("""
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
""")
# Out:
#   schemaname    tablename tableowner tablespace  hasindexes  hasrules  \
# 0         v1  raw_events2      suhel       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
### For a given table, show the columns
pd.DataFrame({c.name:c.__dict__ for c in meta.tables['v1.raw_events'].columns}).T
# Out:
#                    key        name          table     type is_literal  \
# id                  id          id  v1.raw_events  INTEGER      False
# event_name  event_name  event_name  v1.raw_events  VARCHAR      False
# inputs          inputs      inputs  v1.raw_events    JSONB      False
# outputs        outputs     outputs  v1.raw_events    JSONB      False
# metadata      metadata    metadata  v1.raw_events    JSONB      False
#
#            primary_key _user_defined_nullable nullable default  \
# id                True                  False    False    None
# event_name       False                  False    False    None
# inputs           False                   True     True    None
# outputs          False                   True     True    None
# metadata         False                   True     True    None
#
#                                                server_default  ...  \
# id          DefaultClause(<sqlalchemy.sql.elements.TextCla...  ...
# event_name                                               None  ...
# inputs                                                   None  ...
# outputs                                                  None  ...
# metadata                                                 None  ...
#
#            constraints foreign_keys comment computed identity _creation_order  \
# id                  {}           {}    None     None     None              93
# event_name          {}           {}    None     None     None              94
# inputs              {}           {}    None     None     None              95
# outputs             {}           {}    None     None     None              96
# metadata            {}           {}    None     None     None              97
#
#                                                      dispatch  \
# id          <sqlalchemy.event.base.DDLEventsDispatch objec...
# event_name  <sqlalchemy.event.base.DDLEventsDispatch objec...
# inputs      <sqlalchemy.event.base.DDLEventsDispatch objec...
# outputs     <sqlalchemy.event.base.DDLEventsDispatch objec...
# metadata    <sqlalchemy.event.base.DDLEventsDispatch objec...
#
#                                                    comparator _memoized_keys  \
# id          <sqlalchemy.sql.sqltypes._LookupExpressionAdap...   (comparator)
# event_name  <sqlalchemy.sql.sqltypes.Concatenable.Comparat...   (comparator)
# inputs      <sqlalchemy.dialects.postgresql.json.JSONB.Com...   (comparator)
# outputs     <sqlalchemy.dialects.postgresql.json.JSONB.Com...   (comparator)
# metadata    <sqlalchemy.dialects.postgresql.json.JSONB.Com...   (comparator)
#
#            description
# id                  id
# event_name  event_name
# inputs          inputs
# outputs        outputs
# metadata      metadata
#
# [5 rows x 27 columns]

# %%
### Define a table
rawEvents = Table('raw_events',meta,
    Column('id', pgt.INTEGER, primary_key=True, autoincrement=True),
    Column('event_name', pgt.VARCHAR, nullable=False),
    Column('inputs', pgt.JSONB),
    Column('outputs', pgt.JSONB),
    Column('metadata', pgt.JSONB),
    extend_existing=True,
)

# %%
### Create the table 
rawEvents.create()

# %%
### Drop the table
rawEvents.drop()

# %%
### Instantiate example data
captured_examples = """
{'event_name': 'connect', 'inputs': None, 'outputs': None}
{'event_name': 'disconnect', 'inputs': None, 'outputs': None}
{'event_name': 'start_session', 'inputs': {'userName': 'Suhel', 'sessionTag': 'debug'}, 'outputs': 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e'}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 99, 'n2': 96, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 29, 'n2': 18, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'start_session', 'inputs': {'userName': 'Suhel', 'sessionTag': 'debug'}, 'outputs': 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e'}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 19, 'n2': 14, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'connect', 'inputs': None, 'outputs': None}
{'event_name': 'start_session', 'inputs': {'userName': 'Suhel', 'sessionTag': 'debug'}, 'outputs': 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e'}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 33, 'n2': 12, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'send_answer', 'inputs': {'answer': '234234', 'elapsedTime': 2, 'prompt': {'n1': 33, 'n2': 12}}, 'outputs': {'providedAnswer': 234234.0, 'correctAnswer': 396.0, 'pctError': 590.5, 'score': 0.08453085376162299}}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 84, 'n2': 71, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'send_answer', 'inputs': {'answer': '234', 'elapsedTime': 9, 'prompt': {'n1': 84, 'n2': 71}}, 'outputs': {'providedAnswer': 234.0, 'correctAnswer': 5964.0, 'pctError': 0.9607645875251509, 'score': 1.9617706237424548}}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 88, 'n2': 90, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'disconnect', 'inputs': None, 'outputs': None}
"""
event_log = pd.DataFrame(list(map(eval, captured_examples[1:-1].split('\n'))))
event_log
# Out:
#        event_name                                             inputs  \
# 0         connect                                               None
# 1      disconnect                                               None
# 2   start_session       {'userName': 'Suhel', 'sessionTag': 'debug'}
# 3    fetch_prompt                                                 {}
# 4    fetch_prompt                                                 {}
# 5   start_session       {'userName': 'Suhel', 'sessionTag': 'debug'}
# 6    fetch_prompt                                                 {}
# 7         connect                                               None
# 8   start_session       {'userName': 'Suhel', 'sessionTag': 'debug'}
# 9    fetch_prompt                                                 {}
# 10    send_answer  {'answer': '234234', 'elapsedTime': 2, 'prompt...
# 11   fetch_prompt                                                 {}
# 12    send_answer  {'answer': '234', 'elapsedTime': 9, 'prompt': ...
# 13   fetch_prompt                                                 {}
# 14     disconnect                                               None
#
#                                               outputs
# 0                                                None
# 1                                                None
# 2            bb3f11f57b47ed89e02067c5559e1c23dffc6a9e
# 3   {'n1': 99, 'n2': 96, 'promptModel': 'random2di...
# 4   {'n1': 29, 'n2': 18, 'promptModel': 'random2di...
# 5            bb3f11f57b47ed89e02067c5559e1c23dffc6a9e
# 6   {'n1': 19, 'n2': 14, 'promptModel': 'random2di...
# 7                                                None
# 8            bb3f11f57b47ed89e02067c5559e1c23dffc6a9e
# 9   {'n1': 33, 'n2': 12, 'promptModel': 'random2di...
# 10  {'providedAnswer': 234234.0, 'correctAnswer': ...
# 11  {'n1': 84, 'n2': 71, 'promptModel': 'random2di...
# 12  {'providedAnswer': 234.0, 'correctAnswer': 596...
# 13  {'n1': 88, 'n2': 90, 'promptModel': 'random2di...
# 14                                               None

# %%
### Insert a single row (can run this multiple times)
row = event_log.sample().iloc[0]

pg.engine.execute(
    rawEvents.insert().values(**row)
)

# %%
### Read rows directly
pg.read("""SELECT * FROM v1.raw_events""")
# Out:
#    id     event_name                                        inputs  \
# 0   1     disconnect                                          None
# 1   2  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 2   3   fetch_prompt                                            {}
#
#                                              outputs metadata
# 0                                               None     None
# 1           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 2  {'n1': 88, 'n2': 90, 'promptModel': 'random2di...     None

# %%
### Read rows through the cursor (ugh)
pg.engine.execute( 
    rawEvents.select().limit(10)
).fetchall()
# Out:
# [(19, 'connect', None, None, None),
#  (20, 'disconnect', None, None, None),
#  (21, 'start_session', {'userName': 'Suhel', 'sessionTag': 'debug'}, 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e', None),
#  (22, 'fetch_prompt', {}, {'n1': 99, 'n2': 96, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}, None),
#  (23, 'fetch_prompt', {}, {'n1': 29, 'n2': 18, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}, None),
#  (24, 'start_session', {'userName': 'Suhel', 'sessionTag': 'debug'}, 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e', None),
#  (25, 'fetch_prompt', {}, {'n1': 19, 'n2': 14, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}, None),
#  (26, 'connect', None, None, None),
#  (27, 'start_session', {'userName': 'Suhel', 'sessionTag': 'debug'}, 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e', None),
#  (28, 'fetch_prompt', {}, {'n1': 33, 'n2': 12, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}, None)]

# %%
### lol or do it this way

print(
    rawEvents.select().limit(10).compile(compile_kwargs={"literal_binds": True})
)
pg.read(str(
    rawEvents.select().limit(10).compile(compile_kwargs={"literal_binds": True})
))
# Out:
# SELECT v1.raw_events.id, v1.raw_events.event_name, v1.raw_events.inputs, v1.raw_events.outputs, v1.raw_events.metadata
# FROM v1.raw_events
#  LIMIT 10
#    id     event_name                                        inputs  \
# 0  19        connect                                          None
# 1  20     disconnect                                          None
# 2  21  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 3  22   fetch_prompt                                            {}
# 4  23   fetch_prompt                                            {}
# 5  24  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 6  25   fetch_prompt                                            {}
# 7  26        connect                                          None
# 8  27  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 9  28   fetch_prompt                                            {}
#
#                                              outputs metadata
# 0                                               None     None
# 1                                               None     None
# 2           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 3  {'n1': 99, 'n2': 96, 'promptModel': 'random2di...     None
# 4  {'n1': 29, 'n2': 18, 'promptModel': 'random2di...     None
# 5           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 6  {'n1': 19, 'n2': 14, 'promptModel': 'random2di...     None
# 7                                               None     None
# 8           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 9  {'n1': 33, 'n2': 12, 'promptModel': 'random2di...     None

# %%
### Insert the whole df
dtypes = {c.name:c.type for c in rawEvents.columns}  # you need to get the dtypes first (wtf)
event_log.to_sql(name='raw_events',schema='v1',index=None,con=pg.engine, if_exists='append', dtype=dtypes)
pg.read("""SELECT * FROM v1.raw_events""")[:10]
# Out:
#    id     event_name                                        inputs  \
# 0  19        connect                                          None
# 1  20     disconnect                                          None
# 2  21  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 3  22   fetch_prompt                                            {}
# 4  23   fetch_prompt                                            {}
# 5  24  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 6  25   fetch_prompt                                            {}
# 7  26        connect                                          None
# 8  27  start_session  {'userName': 'Suhel', 'sessionTag': 'debug'}
# 9  28   fetch_prompt                                            {}
#
#                                              outputs metadata
# 0                                               None     None
# 1                                               None     None
# 2           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 3  {'n1': 99, 'n2': 96, 'promptModel': 'random2di...     None
# 4  {'n1': 29, 'n2': 18, 'promptModel': 'random2di...     None
# 5           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 6  {'n1': 19, 'n2': 14, 'promptModel': 'random2di...     None
# 7                                               None     None
# 8           bb3f11f57b47ed89e02067c5559e1c23dffc6a9e     None
# 9  {'n1': 33, 'n2': 12, 'promptModel': 'random2di...     None

# %%
### Truncate everything
pg.engine.execute(rawEvents.delete())

# %% [markdown]
# ### Init DB

# %% [raw]
# from db.database import init_db, drop_all

# %% [raw]
# ### Create the database
# from pg import get_pg
# pg = get_pg('sandbox')
# pg.execute("""
# CREATE DATABASE estimate_t1
# """)

# %% [raw]
# init_db()

# %% [raw]
# drop_all()

# %% [markdown]
# ### Testing some shiz

# %%
from db.database import db_session
from db.models import (Session, Interactions, RawEventLog)

# %% [markdown]
# ##### Sessions

# %%
sess = Session(socket_id='asdlkfjs',session_tag='practice',user='suhel')

# %%
db_session.add(sess)
db_session.commit()

# %% [markdown]
# ##### Raw Event Logs

# %%
### Instantiate example data
captured_examples = """
{'event_name': 'connect', 'inputs': None, 'outputs': None}
{'event_name': 'disconnect', 'inputs': None, 'outputs': None}
{'event_name': 'start_session', 'inputs': {'userName': 'Suhel', 'sessionTag': 'debug'}, 'outputs': 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e'}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 99, 'n2': 96, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 29, 'n2': 18, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'start_session', 'inputs': {'userName': 'Suhel', 'sessionTag': 'debug'}, 'outputs': 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e'}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 19, 'n2': 14, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'connect', 'inputs': None, 'outputs': None}
{'event_name': 'start_session', 'inputs': {'userName': 'Suhel', 'sessionTag': 'debug'}, 'outputs': 'bb3f11f57b47ed89e02067c5559e1c23dffc6a9e'}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 33, 'n2': 12, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'send_answer', 'inputs': {'answer': '234234', 'elapsedTime': 2, 'prompt': {'n1': 33, 'n2': 12}}, 'outputs': {'providedAnswer': 234234.0, 'correctAnswer': 396.0, 'pctError': 590.5, 'score': 0.08453085376162299}}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 84, 'n2': 71, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'send_answer', 'inputs': {'answer': '234', 'elapsedTime': 9, 'prompt': {'n1': 84, 'n2': 71}}, 'outputs': {'providedAnswer': 234.0, 'correctAnswer': 5964.0, 'pctError': 0.9607645875251509, 'score': 1.9617706237424548}}
{'event_name': 'fetch_prompt', 'inputs': {}, 'outputs': {'n1': 88, 'n2': 90, 'promptModel': 'random2digits', 'accuracyModel': 'estimate'}}
{'event_name': 'disconnect', 'inputs': None, 'outputs': None}
"""
event_log = pd.DataFrame(list(map(eval, captured_examples[1:-1].split('\n'))))
event_log.at[:,'meta'] = [{'timestamp':pd.Timestamp.now().isoformat(), 'socket_id':'FUCK'}]*event_log.shape[0]

# %%
for index,row in event_log.iterrows():
    re = RawEventLog(**row)
    db_session.add(re)

# %%
db_session.commit()

# %%
res=RawEventLog.query.all()

# %%
res[3].__dict__
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState at 0x7f50d2deaee0>,
#  'event_name': 'fetch_prompt',
#  'outputs': {'n1': 99,
#   'n2': 96,
#   'promptModel': 'random2digits',
#   'accuracyModel': 'estimate'},
#  'meta': {'socket_id': 'FUCK', 'timestamp': '2022-02-09T04:59:06.443718'},
#  'inputs': {},
#  'event_id': 4}

# %% [markdown]
# ##### Interactions

# %%
row = event_log.loc[10].copy()

# %%
row
# Out:
# event_name                                          send_answer
# inputs        {'answer': '234234', 'elapsedTime': 2, 'prompt...
# outputs       {'providedAnswer': 234234.0, 'correctAnswer': ...
# meta          {'timestamp': '2022-02-09T05:07:23.564978', 's...
# Name: 10, dtype: object

# %%
prompt = row['inputs'].pop('prompt')
response = row['inputs']

# %%
review = {}

# %%
session_id = 'sdflkjsdf;ljslfs;dfl'

# %%
i = Interactions(session_id,prompt,response,review)

# %%
db_session.add(i)

# %% [raw]
# db_session.commit()

# %% [markdown]
# ### Explore the db yo

# %%
from pg import get_pg
pg = get_pg('estimate_t1')

# %%
pg.read("""
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
""")
# Out:
#   schemaname     tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public    raw_events      suhel       None        True     False
# 1     public      sessions      suhel       None        True     False
# 2     public  interactions      suhel       None        True     False
#
#    hastriggers  rowsecurity
# 0        False        False
# 1         True        False
# 2         True        False

# %%
pg.read("""
SELECT *
FROM raw_events
""").tail(10)
# Out:
#     event_id    event_name                                             inputs  \
# 30        31   send_answer  {'answer': '234', 'prompt': {'n1': 31, 'n2': 5...
# 31        32  fetch_prompt  {'sessionId': 'a342b5919bff18af0e8e43ed50f4074...
# 32        33   send_answer  {'answer': '23524', 'prompt': {'n1': 70, 'n2':...
# 33        34  fetch_prompt  {'sessionId': 'a342b5919bff18af0e8e43ed50f4074...
# 34        35   send_answer  {'answer': '2356', 'prompt': {'n1': 68, 'n2': ...
# 35        36  fetch_prompt  {'sessionId': 'a342b5919bff18af0e8e43ed50f4074...
# 36        37   send_answer  {'answer': '2357', 'prompt': {'n1': 38, 'n2': ...
# 37        38  fetch_prompt  {'sessionId': 'a342b5919bff18af0e8e43ed50f4074...
# 38        39   send_answer  {'answer': '1', 'prompt': {'n1': 88, 'n2': 30}...
# 39        40  fetch_prompt  {'sessionId': 'a342b5919bff18af0e8e43ed50f4074...
#
#                                               outputs  \
# 30  {'score': 6.507230255839821, 'pctError': 0.869...
# 31  {'n1': 70, 'n2': 66, 'promptModel': 'random2di...
# 32  {'score': 9.819758544465227, 'pctError': 4.091...
# 33  {'n1': 68, 'n2': 38, 'promptModel': 'random2di...
# 34  {'score': 45.588235294117645, 'pctError': 0.08...
# 35  {'n1': 38, 'n2': 11, 'promptModel': 'random2di...
# 36  {'score': 8.867204072974118, 'pctError': 4.638...
# 37  {'n1': 88, 'n2': 30, 'promptModel': 'random2di...
# 38  {'score': 0.01893939393939394, 'pctError': 0.9...
# 39  {'n1': 69, 'n2': 10, 'promptModel': 'random2di...
#
#                                                  meta
# 30  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 31  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 32  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 33  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 34  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 35  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 36  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 37  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 38  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...
# 39  {'socket_id': 'wH0iu0Dp17Pk0hdPAAAB', 'timesta...

# %%
pg.read("""
SELECT *
FROM sessions
""").tail(10)
# Out:
#                                  session_id             socket_id session_tag  \
# 0  9d9097a2aeb067e4c325e91026fc8d016c199066  wH0iu0Dp17Pk0hdPAAAB        test
# 1  a342b5919bff18af0e8e43ed50f40745f4daad9f  wH0iu0Dp17Pk0hdPAAAB       debug
#
#     user                  timestamp
# 0  Suhel 2022-02-09 05:32:21.125715
# 1  Suhel 2022-02-09 05:32:40.787771

# %%
pg.read("""
SELECT *
FROM interactions
""").tail(10)
# Out:
#     interaction_id                                session_id  \
# 7                8  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 8                9  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 9               10  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 10              11  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 11              12  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 12              13  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 13              14  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 14              15  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 15              16  a342b5919bff18af0e8e43ed50f40745f4daad9f
# 16              17  a342b5919bff18af0e8e43ed50f40745f4daad9f
#
#                   prompt                               response  \
# 7   {'n1': 58, 'n2': 64}   {'answer': '2342', 'elapsedTime': 1}
# 8   {'n1': 13, 'n2': 12}   {'answer': '2342', 'elapsedTime': 0}
# 9   {'n1': 72, 'n2': 11}   {'answer': '1355', 'elapsedTime': 1}
# 10  {'n1': 40, 'n2': 80}  {'answer': '34574', 'elapsedTime': 0}
# 11  {'n1': 12, 'n2': 51}  {'answer': '43564', 'elapsedTime': 0}
# 12  {'n1': 31, 'n2': 58}    {'answer': '234', 'elapsedTime': 0}
# 13  {'n1': 70, 'n2': 66}  {'answer': '23524', 'elapsedTime': 1}
# 14  {'n1': 68, 'n2': 38}   {'answer': '2356', 'elapsedTime': 0}
# 15  {'n1': 38, 'n2': 11}   {'answer': '2357', 'elapsedTime': 1}
# 16  {'n1': 88, 'n2': 30}      {'answer': '1', 'elapsedTime': 3}
#
#                                                review  \
# 7   {'score': 31.54633620689655, 'pctError': 0.369...
# 8   {'score': 3.330486763450043, 'pctError': 14.01...
# 9   {'score': 29.225092250922508, 'pctError': 0.71...
# 10  {'score': 4.6277549603748485, 'pctError': 9.80...
# 11  {'score': 0.7024148379395831, 'pctError': 70.1...
# 12  {'score': 6.507230255839821, 'pctError': 0.869...
# 13  {'score': 9.819758544465227, 'pctError': 4.091...
# 14  {'score': 45.588235294117645, 'pctError': 0.08...
# 15  {'score': 8.867204072974118, 'pctError': 4.638...
# 16  {'score': 0.01893939393939394, 'pctError': 0.9...
#
#            timestamp_received
# 7  2022-02-09 05:32:42.114777
# 8  2022-02-09 05:32:43.259017
# 9  2022-02-09 05:32:44.855707
# 10 2022-02-09 05:32:46.140025
# 11 2022-02-09 05:32:47.503673
# 12 2022-02-09 05:32:49.389717
# 13 2022-02-09 05:32:51.736656
# 14 2022-02-09 05:32:53.213654
# 15 2022-02-09 05:32:54.628937
# 16 2022-02-09 05:32:58.068604
